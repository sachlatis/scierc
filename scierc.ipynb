# %%
# !git clone https://github.com/sachlatis/scierc.git
# %cd /kaggle/working/scierc/data
# %cd /kaggle/working/scierc/model
# !touch pytorch_model.bin
# %cd /kaggle/working/scierc/src
# Out:
# Cloning into 'scierc'...
# remote: Enumerating objects: 87, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 87 (delta 36), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (87/87), done.
# /kaggle/working/scierc/data
# /kaggle/working/scierc/model
# /kaggle/working/scierc/src

# %%
# !python3 sentence_classifier.py --mode train
# Out:
# 2021-09-06 21:53:57.337592: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# There are 1 GPU(s) available.
# We will use the GPU: Tesla P100-PCIE-16GB
# Downloading: 100%|████████████████████████████| 232k/232k [00:00<00:00, 940kB/s]
# Downloading: 100%|███████████████████████████| 28.0/28.0 [00:00<00:00, 34.8kB/s]
# Downloading: 100%|███████████████████████████| 466k/466k [00:00<00:00, 1.83MB/s]
# Downloading: 100%|██████████████████████████████| 570/570 [00:00<00:00, 643kB/s]
# Downloading: 100%|███████████████████████████| 440M/440M [00:09<00:00, 46.6MB/s]
# ...

# %%
# !zip -r /kaggle/working/scierc.zip /kaggle/working/scierc/model
# Out:
#   adding: kaggle/working/scierc/model/ (stored 0%)
#   adding: kaggle/working/scierc/model/pytorch_model.bin (deflated 7%)
#   adding: kaggle/working/scierc/model/config.json (deflated 54%)
#   adding: kaggle/working/scierc/model/vocab.txt (deflated 53%)

# %%
# !python3 sentence_classifier.py --mode eval
# Out:
# 2021-09-06 22:00:09.682415: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# There are 1 GPU(s) available.
# We will use the GPU: Tesla P100-PCIE-16GB
# DONE.
#               precision    recall  f1-score   support
#
#      compare     0.9143    0.8421    0.8767       152
#  conjunction     0.8750    0.9675    0.9189       492
# evaluate-for     0.8172    0.8352    0.8261       364
#   feature-of     0.6182    0.5763    0.5965       236
#   hyponym-of     0.8611    0.9254    0.8921       268
#      part-of     0.6066    0.5873    0.5968       252
#     used-for     0.9349    0.9156    0.9251      2132
#
#     accuracy                         0.8706      3896
#    macro avg     0.8039    0.8070    0.8046      3896
# weighted avg     0.8700    0.8706    0.8698      3896
#
#
# 0.8706365503080082
